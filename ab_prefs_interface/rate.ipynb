# %% [markdown]
# # ASR A/B preference rating
#
# 1. Edit **RATER_ID** below (your name, no spaces)
# 2. **Run All** or run the code cell
# 3. Use the audio player + **Choose A / B / Tie / Skip** buttons
# 4. When done, run the summarize command printed in the notebook output
#
# Paths and item list come from `configs/ab_prefs.session.json` (set up by lead).

# %%
import os, sys
from pathlib import Path

# find repo root (contains configs/ab_prefs.session.json)
repo = Path.cwd()
for _ in range(6):
    if (repo / "configs" / "ab_prefs.session.json").exists():
        break
    repo = repo.parent
else:
    repo = Path("/home/rosy_teachfx_com/asr_eval")
os.chdir(repo)
if str(repo) not in sys.path:
    sys.path.insert(0, str(repo))

RATER_ID = "Rosy2"  # update with your name

from ab_prefs_interface.launch import launch_rating
launch_rating(RATER_ID)
# Out:
# Rater: Rosy2 → /home/rosy_teachfx_com/asr_eval/results/ab_prefs/preferences_Rosy2.json
# Session config: /home/rosy_teachfx_com/asr_eval/configs/ab_prefs.session.json
# Items from: /home/rosy_teachfx_com/asr_eval/configs/ab_prefs.manifest.json
#
# Summarize after rating (separate, optional):
# python -m ab_prefs_interface.summarize_preferences --input-json /home/rosy_teachfx_com/asr_eval/results/ab_prefs/preferences_Rosy2.json --ground-truth-name ground_truth
# Loading comparison units...
# Demo mode: 5 / 210 recordings (seed=7): ['263682', '269830', '275140', '278341', '306159']
# GT recordings: 5 · providers: 9
# merge rules: min_gt_words=5, min_audio_seconds=3.0
# ~2476 raw GT lines → fewer units after merge (load JSON + word overlap per unit×provider)
# demo cache key d99f712fae794b39 under /home/rosy_teachfx_com/asr_eval/results/ab_prefs/unit_cache/demo
# build units (recordings): 100%|██████████| 5/5 [00:00<00:00, 25.18it/s, n_seg=569, recording_id=306159]
# ...
